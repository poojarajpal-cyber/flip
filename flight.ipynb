# %%
import pandas as pd
import numpy as np

# %%
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver_win32\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="e4453fae4740a777bae2a6cb68b79f5e")>

# %%
driver.maximize_window()

# %%
url='https://www.yatra.com/'
driver.get(url)

# %%
names=[]
name_tag=driver.find_elements(By.XPATH,'//span[@class="i-b text ellipsis"]')
for i in name_tag:
    names.append(i.text)
names
# Out:
# ['Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo']

# %%
len(names)
# Out:
# 14

# %%
date=[]
date_tag=driver.find_elements(By.XPATH,'//p[@class="fs-12"]')
for i in date_tag[0:14]:
    date.append(i.text)
date
# Out:
# ['Mon, 6 Feb',
#  'Tue, 7 Feb',
#  'Wed, 8 Feb',
#  'Thu, 9 Feb',
#  'Fri, 10 Feb',
#  'Sat, 11 Feb',
#  'Sun, 12 Feb',
#  'Mon, 13 Feb',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
len(date)
# Out:
# 14

# %%
source=[]
source_tag=driver.find_elements(By.XPATH,'//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
for i in source_tag[0:14]:
    source.append(i.text)
source
# Out:
# ['New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai']

# %%
len(source)
# Out:
# 14

# %%
route=[]
route_tag=driver.find_elements(By.XPATH,'//div[@class="mb-8 yellow-msg text-center fs-13"]')
for i in route_tag:
    route.append(i.text)
route
# Out:
# ['Change plane at Ahmedabad (AMD), Connecting Time: 6h 10m']

# %%
dtime=[]
departure_tag=driver.find_elements(By.XPATH,'//div[@class="i-b pr"]')
for i in departure_tag:
    dtime.append(i.text)
dtime
# Out:
# ['05:00',
#  '21:20',
#  '18:00',
#  '13:25',
#  '06:30',
#  '21:20',
#  '18:00',
#  '13:25',
#  '04:55',
#  '08:10',
#  '08:10',
#  '11:05',
#  '23:40',
#  '06:20']

# %%
len(dtime)
# Out:
# 14

# %%
atime=[]
arrival_tag=driver.find_elements(By.XPATH,'//div[@class="i-b pdd-0 text-left atime col-5"]')
for i in arrival_tag:
    atime.append(i.text)
atime
# Out:
# ['10:45\nMumbai',
#  '06:15\n+ 1 day\nMumbai',
#  '06:15\n+ 1 day\nMumbai',
#  '06:15\n+ 1 day\nMumbai',
#  '06:15\n+ 1 day\nMumbai',
#  '09:40\n+ 1 day\nMumbai',
#  '09:40\n+ 1 day\nMumbai',
#  '09:40\n+ 1 day\nMumbai',
#  '10:50\nMumbai',
#  '19:00\nMumbai',
#  '21:00\nMumbai',
#  '16:45\nMumbai',
#  '05:50\n+ 1 day\nMumbai',
#  '16:10\nMumbai']

# %%
len(atime)
# Out:
# 14

# %%
duration=[]
duration_tag=driver.find_elements(By.XPATH,'//p[@class="fs-12 bold du mb-2"]')
for i in duration_tag:
    duration.append(i.text)
duration
# Out:
# ['5h 45m',
#  '8h 55m',
#  '12h 15m',
#  '16h 50m',
#  '23h 45m',
#  '12h 20m',
#  '15h 40m',
#  '20h 15m',
#  '5h 55m',
#  '10h 50m',
#  '12h 50m',
#  '5h 40m',
#  '6h 10m',
#  '9h 50m']

# %%
len(duration)
# Out:
# 14

# %%
stops=[]
stop_tag=driver.find_elements(By.XPATH,'//span[@class="dotted-borderbtm"]')
for i in stop_tag:
    stops.append(i.text)
stops
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop']

# %%
len(stops)
# Out:
# 14

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in price_tag:
    price.append(i.text)
price
# Out:
# ['4,093',
#  '4,102',
#  '4,102',
#  '4,102',
#  '4,102',
#  '4,737',
#  '4,737',
#  '4,737',
#  '4,827',
#  '4,827',
#  '4,827',
#  '5,176',
#  '5,241',
#  '5,241']

# %%
len(price)
# Out:
# 14

# %%
flight=pd.DataFrame()
flight['Names']=names
flight['Date']=date
flight['Places']=source
flight['Departure']=dtime
flight['Arrival']=atime
flight['Duration']=duration
flight['Price']=price
flight
# Out:
#        Names         Date     Places Departure                 Arrival  \
# 0   Go First   Mon, 6 Feb  New Delhi     05:00           10:45\nMumbai
# 1    Vistara   Tue, 7 Feb     Mumbai     21:20  06:15\n+ 1 day\nMumbai
# 2    Vistara   Wed, 8 Feb  New Delhi     18:00  06:15\n+ 1 day\nMumbai
# 3    Vistara   Thu, 9 Feb     Mumbai     13:25  06:15\n+ 1 day\nMumbai
# 4    Vistara  Fri, 10 Feb  New Delhi     06:30  06:15\n+ 1 day\nMumbai
# 5    Vistara  Sat, 11 Feb     Mumbai     21:20  09:40\n+ 1 day\nMumbai
# 6    Vistara  Sun, 12 Feb  New Delhi     18:00  09:40\n+ 1 day\nMumbai
# 7    Vistara  Mon, 13 Feb     Mumbai     13:25  09:40\n+ 1 day\nMumbai
# 8   Air Asia               New Delhi     04:55           10:50\nMumbai
# 9   Air Asia                  Mumbai     08:10           19:00\nMumbai
# 10  Air Asia               New Delhi     08:10           21:00\nMumbai
# 11    IndiGo                  Mumbai     11:05           16:45\nMumbai
# ...

# %%
#lets close the window
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver_win32\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="e7467c29964cd702bcf249abb60fd57f")>

# %%
driver.maximize_window()

# %%
url='https://www.kayak.com/'
driver.get(url)

# %%
srch_place=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/main/div[1]/div[1]/div/div[1]/div/div/section[2]/div/div/div/div/div/div[1]/div[2]/div/div[3]/div/div/input')
srch_place.send_keys("Mumbai")

# %%
srch_btn=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/main/div[1]/div[1]/div/div[1]/div/div/section[2]/div/div/div/div/div/div[1]/div[2]/div/div[5]/button/div[1]/div')
srch_btn.click()

# %%
button=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/main/div[1]/div[1]/div/div[1]/div/div/section[2]/div/div/div/div/div/div[1]/div[2]/div/div[5]/button')
button.click()

# %%
air_name=[]
airname_tag=driver.find_elements(By.XPATH,'//span[@class="codeshares-airline-names"]')
for i in airname_tag[0:14]:
    air_name.append(i.text)
air_name
# Out:
# ['GoFirst',
#  'Vistara, AirAsia India',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst']

# %%
len(air_name)
# Out:
# 14

# %%
sourcee=[]
src_tag=driver.find_elements(By.XPATH,'//span[@class="airport-name"]')
for i in src_tag[0:14]:
    sourcee.append(i.text)
sourcee
# Out:
# ['DEL Indira Gandhi Intl',
#  'BOM Chhatrapati Shivaji Intl',
#  'BOM Chhatrapati Shivaji Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'BOM Chhatrapati Shivaji Intl',
#  'BOM Chhatrapati Shivaji Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'BOM Chhatrapati Shivaji Intl',
#  'BOM Chhatrapati Shivaji Intl',
#  'DEL Indira Gandhi Intl',
#  'DEL Indira Gandhi Intl',
#  'BOM Chhatrapati Shivaji Intl']

# %%
len(sourcee)
# Out:
# 14

# %%
date=[]
dt_tag=driver.find_elements(By.XPATH,'//span[@class="sR_k-date sR_k-mod-hide-arrows sR_k-mod-active"]')
for i in dt_tag[0:14]:
    date.append(i.text)
date
# Out:
# ['Mon 13/2', 'Mon 13/2']

# %%
route=[]
rt_tag=driver.find_elements(By.XPATH,'//span[@class="stops-text"]')
for i in rt_tag[0:14]:
    route.append(i.text)
route
# Out:
# ['direct',
#  'direct',
#  '1 stop',
#  '1 stop',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct']

# %%
len(route)
# Out:
# 14

# %%
departime=[]
depart_tag=driver.find_elements(By.XPATH,'//span[@class="depart-time base-time"]')
for i in depart_tag[0:14]:
    departime.append(i.text)
departime
# Out:
# ['06:00',
#  '09:55',
#  '21:20',
#  '15:15',
#  '06:00',
#  '17:40',
#  '19:40',
#  '20:15',
#  '18:00',
#  '09:55',
#  '14:35',
#  '20:15',
#  '06:00',
#  '08:45']

# %%
len(departime)
# Out:
# 14

# %%
arrivtime=[]
arriv_tag=driver.find_elements(By.XPATH,'//span[@class="arrival-time base-time"]')
for i in arriv_tag[0:14]:
    arrivtime.append(i.text)
arrivtime
# Out:
# ['08:10',
#  '12:05',
#  '06:15',
#  '23:05',
#  '08:10',
#  '19:50',
#  '21:50',
#  '22:25',
#  '20:10',
#  '12:05',
#  '16:45',
#  '22:25',
#  '08:10',
#  '10:55']

# %%
len(arrivtime)
# Out:
# 14

# %%
duration=[]
duration_tag=driver.find_elements(By.XPATH,'//div[@class="section duration allow-multi-modal-icons"]')
for i in duration_tag[0:14]:
    duration.append(i.text)
duration
# Out:
# ['2h 10m',
#  '2h 10m',
#  '8h 55m',
#  '7h 50m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m']

# %%
len(duration)
# Out:
# 14

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//span[@class="price option-text"]')
for i in price_tag[0:14]:
    price.append(i.text)
price
# Out:
# ['₹ 8,398',
#  '₹ 8,495',
#  '',
#  '',
#  '',
#  '',
#  '₹ 8,387',
#  '₹ 8,279',
#  '₹ 8,807',
#  '',
#  '₹ 7,679',
#  '₹ 8,398',
#  '₹ 8,495',
#  '']

# %%
len(price)
# Out:
# 14

# %%
flight_1=pd.DataFrame()
flight_1['Names']=air_name
flight_1['Route']=route
flight_1['Places']=sourcee
flight_1['Departure']=departime
flight_1['Arrival']=arrivtime
flight_1['Duration']=duration
flight_1['Price']=price
flight_1
# Out:
#                      Names   Route                        Places Departure  \
# 0                  GoFirst  direct        DEL Indira Gandhi Intl     06:00
# 1   Vistara, AirAsia India  direct  BOM Chhatrapati Shivaji Intl     09:55
# 2                  GoFirst  1 stop  BOM Chhatrapati Shivaji Intl     21:20
# 3                  GoFirst  1 stop        DEL Indira Gandhi Intl     15:15
# 4                  GoFirst  direct        DEL Indira Gandhi Intl     06:00
# 5                  GoFirst  direct  BOM Chhatrapati Shivaji Intl     17:40
# 6                  GoFirst  direct  BOM Chhatrapati Shivaji Intl     19:40
# 7                  GoFirst  direct        DEL Indira Gandhi Intl     20:15
# 8                  GoFirst  direct        DEL Indira Gandhi Intl     18:00
# 9                  GoFirst  direct  BOM Chhatrapati Shivaji Intl     09:55
# 10                 GoFirst  direct  BOM Chhatrapati Shivaji Intl     14:35
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver_win32\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="0bfd5183b35c5dabb7ad881dc7e8dc12")>

# %%
driver.maximize_window()

# %%
url='https://www.agoda.com/'
driver.get(url)

# %%
btn=driver.find_element(By.XPATH,'/html/body/div[8]/div[2]/div/section/section/div/div[2]/div/div[2]/button/div')
btn.click()

# %%
btn=driver.find_element(By.XPATH,'/html/body/div[8]/div[2]/div/section/section/div/div[2]/ul/li[4]/div/h6')
btn.click()

# %%
airname=[]
name_tag=driver.find_elements(By.XPATH,'//div[@class="Box-sc-kv6pi1-0 jEyiBE FlightSlice__airline--2QesG"]')
for i in name_tag[0:14]:
    airname.append(i.text)
airname
# Out:
# ['GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'GoFirst',
#  'IndiGo',
#  'IndiGo']

# %%
len(airname)
# Out:
# 14

# %%
sourcename=[]
source_tag=driver.find_elements(By.XPATH,'//span[@class="Typographystyled__TypographyStyled-sc-j18mtu-0 hEUAVz kite-js-Typography "]')
for i in source_tag[0:14]:
    sourcename.append(i.text)
sourcename
# Out:
# ['DEL',
#  'BOM',
#  'DEL',
#  'BOM',
#  'DEL',
#  'BOM',
#  'DEL',
#  'BOM',
#  'DEL',
#  'BOM',
#  'DEL',
#  'BOM',
#  'DEL',
#  'BOM']

# %%
len(sourcename)
# Out:
# 14

# %%
route=[]
r_tag=driver.find_elements(By.XPATH,'//div[@class="FlightSegment__duration--2li72"]')
for i in r_tag[0:14]:
    route.append(i.text[7:])
route
# Out:
# ['(1 stop)',
#  ' (1 stop)',
#  '(Direct)',
#  '(Direct)',
#  '(Direct)',
#  '(Direct)',
#  '(Direct)',
#  '(Direct)',
#  '(Direct)',
#  '(Direct)',
#  '1 stop)',
#  '(1 stop)',
#  '(1 stop)',
#  '(1 stop)']

# %%
len(route)
# Out:
# 14

# %%
depart_time=[]
d_tag=driver.find_elements(By.XPATH,'//div[@class="FlightSlice__info--3SYzR FlightSlice__infoLeft--1g8jo"]')
for i in d_tag[0:14]:
    depart_time.append(i.text[0:7])
depart_time
# Out:
# ['06:00\nD',
#  'BOM\n10:',
#  '06:00\nD',
#  'BOM\n16:',
#  '18:00\nD',
#  'BOM\n20:',
#  '14:35\nD',
#  'BOM\n16:',
#  '19:40\nD',
#  'BOM\n21:',
#  '02:40\nD',
#  'BOM\n04:',
#  '06:00\nD',
#  'BOM\n08:']

# %%
a_time=[]
a_tag=driver.find_elements(By.XPATH,'//div[@class="FlightSlice__info--3SYzR FlightSlice__infoLeft--1g8jo"]')
for i in a_tag[0:14]:
    a_time.append(i.text[4:])
a_time
# Out:
# ['0\nDEL',
#  '10:45',
#  '0\nDEL',
#  '16:15',
#  '0\nDEL',
#  '20:10',
#  '5\nDEL',
#  '16:45',
#  '0\nDEL',
#  '21:50',
#  '0\nDEL',
#  '04:50',
#  '0\nDEL',
#  '08:10']

# %%
duration_time=[]
duration_tag=driver.find_elements(By.XPATH,'//span[@class="Typographystyled__TypographyStyled-sc-j18mtu-0 hOvplk kite-js-Typography "]')
for i in duration_tag[0:14]:
    duration_time.append(i.text)
duration_time
# Out:
# ['4h 45m',
#  '10h 15m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 10m',
#  '2h 10m',
#  '5h 0m',
#  '26h 5m',
#  '5h 40m',
#  '5h 20m']

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//span[@class="FlightPrice__price--3zyU4"]')
for i in price_tag[0:14]:
    price.append(i.text)
price
# Out:
# ['4,251.67',
#  '4,251.67',
#  '4,396.78',
#  '4,396.78',
#  '4,396.78',
#  '4,396.78',
#  '4,396.78',
#  '4,396.78',
#  '4,396.78',
#  '4,396.78',
#  '5,139.60',
#  '5,239.99',
#  '5,286.05',
#  '5,395.25']

# %%
flight_2=pd.DataFrame()
flight_2['Names']=airname
flight_2['Route']=route
flight_2['Places']=sourcename
flight_2['Departure']=depart_time
flight_2['Arrival']=a_time
flight_2['Duration']=duration_time
flight_2['Price']=price
flight_2
# Out:
#       Names      Route Places Departure Arrival Duration     Price
# 0   GoFirst   (1 stop)    DEL  06:00\nD  0\nDEL   4h 45m  4,251.67
# 1   GoFirst   (1 stop)    BOM  BOM\n10:   10:45  10h 15m  4,251.67
# 2   GoFirst   (Direct)    DEL  06:00\nD  0\nDEL   2h 10m  4,396.78
# 3   GoFirst   (Direct)    BOM  BOM\n16:   16:15   2h 10m  4,396.78
# 4   GoFirst   (Direct)    DEL  18:00\nD  0\nDEL   2h 10m  4,396.78
# 5   GoFirst   (Direct)    BOM  BOM\n20:   20:10   2h 10m  4,396.78
# 6   GoFirst   (Direct)    DEL  14:35\nD  5\nDEL   2h 10m  4,396.78
# 7   GoFirst   (Direct)    BOM  BOM\n16:   16:45   2h 15m  4,396.78
# 8   GoFirst   (Direct)    DEL  19:40\nD  0\nDEL   2h 10m  4,396.78
# 9   GoFirst   (Direct)    BOM  BOM\n21:   21:50   2h 10m  4,396.78
# 10  GoFirst    1 stop)    DEL  02:40\nD  0\nDEL    5h 0m  5,139.60
# 11  GoFirst   (1 stop)    BOM  BOM\n04:   04:50   26h 5m  5,239.99
# 12   IndiGo   (1 stop)    DEL  06:00\nD  0\nDEL   5h 40m  5,286.05
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver_win32\chromedriver.exe')
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="849ceac6c8bb08b6501e58cc6064eeee")>

# %%
driver.maximize_window()

# %%
url='https://www.cheapOair.com/'
driver.get(url)

# %%
search=driver.find_element(By.XPATH,'/html/body/div[2]/section[3]/div/div[2]/div/div[2]/div[1]/div/div[4]/div/div[1]/div/div[2]/div/input')
search.send_keys('Bangalore')

# %%
btn=driver.find_element(By.XPATH,'/html/body/div[2]/section[3]/div/div[2]/div/div[2]/div[1]/div/div[3]/div/div[4]/input')
btn.click()

# %%
air_name=[]
names=driver.find_elements(By.XPATH,'//div[@class="col-2 trip__airline"]')
for i in names[0:14]:
    air_name.append(i.text)
air_name
# Out:
# ['Air India',
#  'IndiGo Airlines',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo Airlines',
#  'Air India',
#  'IndiGo Airlines',
#  'Air India',
#  'Air India']

# %%
src=[]
src_tag=driver.find_elements(By.XPATH,'//span[@class="is--airport-name pt-1 m-0 "]')
for i in src_tag[0:14]:
    src.append(i.text)
src
# Out:
# ['BOM',
#  'BLR',
#  'BLR',
#  'BOM',
#  'BOM',
#  'BLR',
#  'BLR',
#  'BOM',
#  'BOM',
#  'BLR',
#  'BLR',
#  'BOM',
#  'BOM',
#  'BLR']

# %%
route=[]
r_tag=driver.find_elements(By.XPATH,'//div[@class="stop__number pt-1 stop__number-0"]')
for i in r_tag[0:14]:
    route.append(i.text)
route
# Out:
# ['Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop']

# %%
departure_time=[]
departure_tag=driver.find_elements(By.XPATH,'//li[@class="timeline--list__time text-right"]')
for i in departure_tag[0:14]:
    departure_time.append(i.text[0:6])
departure_time
# Out:
# ['6:45am',
#  '7:25pm',
#  '6:45am',
#  '9:20pm',
#  '4:40pm',
#  '9:20pm',
#  '6:50pm',
#  '9:20pm',
#  '6:45am',
#  '9:30pm',
#  '6:45am',
#  '4:20pm',
#  '6:45am',
#  '7:15pm']

# %%
arrival_time=[]
arrival_tag=driver.find_elements(By.XPATH,'//li[@class="timeline--list__time"]')
for i in arrival_tag[0:14]:
    arrival_time.append(i.text[0:6])
arrival_time
# Out:
# ['8:30am',
#  '9:15pm',
#  '8:30am',
#  '11:20p',
#  '6:25pm',
#  '11:20p',
#  '8:30pm',
#  '11:20p',
#  '8:30am',
#  '11:25p',
#  '8:30am',
#  '6:15pm',
#  '8:30am',
#  '9:30pm']

# %%
duration=[]
duration_tag=driver.find_elements(By.XPATH,'//div[@class="stop__trip-duration"]')
for i in duration_tag[0:14]:
    duration.append(i.text)
duration
# Out:
# ['1h 45m',
#  '1h 50m',
#  '1h 45m',
#  '2h 0m',
#  '1h 45m',
#  '2h 0m',
#  '1h 40m',
#  '2h 0m',
#  '1h 45m',
#  '1h 55m',
#  '1h 45m',
#  '1h 55m',
#  '1h 45m',
#  '2h 15m']

# %%
stops=[]
stops_tag=driver.find_elements(By.XPATH,'//div[@class="stop__number pt-1 stop__number-0"]')
for i in stops_tag[0:14]:
    stops.append(i.text)
stops
# Out:
# ['Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop',
#  'Non stop']

# %%
price=[]
price_tag=driver.find_elements(By.XPATH,'//div[@class="fare-details__fare"]')
for i in price_tag[0:14]:
    price.append(i.text)
price
# Out:
# ['USD 60.99',
#  'USD 61.70',
#  'USD 61.70',
#  'USD 61.70',
#  'USD 60.99',
#  'USD 60.99',
#  'USD 63.80',
#  'USD 60.99',
#  'USD 61.70',
#  'USD 66.91',
#  'USD 60.99',
#  'USD 63.80',
#  'USD 66.91',
#  'USD 60.99']

# %%
flight_3=pd.DataFrame()
flight_3['Names']=air_name
flight_3['Route']=route
flight_3['Places']=src
flight_3['Departure']=departure_time
flight_3['Arrival']=arrival_time
flight_3['Duration']=duration
flight_3['Price']=price
flight_3
# Out:
#               Names     Route Places Departure Arrival Duration      Price
# 0         Air India  Non stop    BOM    6:45am  8:30am   1h 45m  USD 60.99
# 1   IndiGo Airlines  Non stop    BLR    7:25pm  9:15pm   1h 50m  USD 61.70
# 2         Air India  Non stop    BLR    6:45am  8:30am   1h 45m  USD 61.70
# 3         Air India  Non stop    BOM    9:20pm  11:20p    2h 0m  USD 61.70
# 4         Air India  Non stop    BOM    4:40pm  6:25pm   1h 45m  USD 60.99
# 5         Air India  Non stop    BLR    9:20pm  11:20p    2h 0m  USD 60.99
# 6         Air India  Non stop    BLR    6:50pm  8:30pm   1h 40m  USD 63.80
# 7         Air India  Non stop    BOM    9:20pm  11:20p    2h 0m  USD 60.99
# 8         Air India  Non stop    BOM    6:45am  8:30am   1h 45m  USD 61.70
# 9   IndiGo Airlines  Non stop    BLR    9:30pm  11:25p   1h 55m  USD 66.91
# 10        Air India  Non stop    BLR    6:45am  8:30am   1h 45m  USD 60.99
# ...

# %%
driver.close()

# %%
df=pd.concat([flight,flight_1,flight_2,flight_3])
df
# Out:
#                      Names         Date                        Places  \
# 0                 Go First   Mon, 6 Feb                     New Delhi
# 1                  Vistara   Tue, 7 Feb                        Mumbai
# 2                  Vistara   Wed, 8 Feb                     New Delhi
# 3                  Vistara   Thu, 9 Feb                        Mumbai
# 4                  Vistara  Fri, 10 Feb                     New Delhi
# 5                  Vistara  Sat, 11 Feb                        Mumbai
# 6                  Vistara  Sun, 12 Feb                     New Delhi
# 7                  Vistara  Mon, 13 Feb                        Mumbai
# 8                 Air Asia                                  New Delhi
# 9                 Air Asia                                     Mumbai
# 10                Air Asia                                  New Delhi
# 11                  IndiGo                                     Mumbai
# ...

# %%
df.shape
# Out:
# (56, 8)

# %%
df.dtypes
# Out:
# Names        object
# Date         object
# Places       object
# Departure    object
# Arrival      object
# Duration     object
# Price        object
# Route        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Names         0
# Date         42
# Places        0
# Departure     0
# Arrival       0
# Duration      0
# Price         0
# Route        14
# dtype: int64

# %%
# lets treat nulls
df['Date']=df['Date'].fillna(df['Date'].mode())

# %%
df['Route']=df['Route'].fillna("Non stop")

# %%
df.isnull().sum()
# Out:
# Names         0
# Date         39
# Places        0
# Departure     0
# Arrival       0
# Duration      0
# Price         0
# Route         0
# dtype: int64

# %%
print(df["Date"].value_counts())
# Out:
#                9
# Mon, 6 Feb     1
# Tue, 7 Feb     1
# Wed, 8 Feb     1
# Thu, 9 Feb     1
# Fri, 10 Feb    1
# Sat, 11 Feb    1
# Sun, 12 Feb    1
# Mon, 13 Feb    1
# Name: Date, dtype: int64

# %%
print(df["Route"].value_counts())
# Out:
# Non stop     15
# direct       12
# (Direct)      8
# (1 stop)      4
# 1 stop        2
#  (1 stop)     1
# 1 stop)       1
# Name: Route, dtype: int64

# %%
df['Date'].nunique()
# Out:
# 9

# %%
df
# Out:
#                      Names         Date                        Places  \
# 0                 Go First   Mon, 6 Feb                     New Delhi
# 1                  Vistara   Tue, 7 Feb                        Mumbai
# 2                  Vistara   Wed, 8 Feb                     New Delhi
# 3                  Vistara   Thu, 9 Feb                        Mumbai
# 4                  Vistara  Fri, 10 Feb                     New Delhi
# 5                  Vistara  Sat, 11 Feb                        Mumbai
# 6                  Vistara  Sun, 12 Feb                     New Delhi
# 7                  Vistara  Mon, 13 Feb                        Mumbai
# 8                 Air Asia                                  New Delhi
# 9                 Air Asia                                     Mumbai
# 10                Air Asia                                  New Delhi
# 11                  IndiGo                                     Mumbai
# ...

# %%
# lets treat nulls
df['Date']=df['Date'].fillna('Mon, 14 Feb ')

# %%
df.isnull().sum()
# Out:
# Names        0
# Date         0
# Places       0
# Departure    0
# Arrival      0
# Duration     0
# Price        0
# Route        0
# dtype: int64

# %%
df
# Out:
#                      Names          Date                        Places  \
# 0                 Go First    Mon, 6 Feb                     New Delhi
# 1                  Vistara    Tue, 7 Feb                        Mumbai
# 2                  Vistara    Wed, 8 Feb                     New Delhi
# 3                  Vistara    Thu, 9 Feb                        Mumbai
# 4                  Vistara   Fri, 10 Feb                     New Delhi
# 5                  Vistara   Sat, 11 Feb                        Mumbai
# 6                  Vistara   Sun, 12 Feb                     New Delhi
# 7                  Vistara   Mon, 13 Feb                        Mumbai
# 8                 Air Asia                                   New Delhi
# 9                 Air Asia                                      Mumbai
# 10                Air Asia                                   New Delhi
# 11                  IndiGo                                      Mumbai
# ...

# %%
df['Date'].nunique()
# Out:
# 10

# %%
df.loc[df['Date']=='']
# Out:
#         Names Date                  Places Departure                 Arrival  \
# 8    Air Asia                    New Delhi     04:55           10:50\nMumbai
# 9    Air Asia                       Mumbai     08:10           19:00\nMumbai
# 10   Air Asia                    New Delhi     08:10           21:00\nMumbai
# 11     IndiGo                       Mumbai     11:05           16:45\nMumbai
# 12     IndiGo                    New Delhi     23:40  05:50\n+ 1 day\nMumbai
# 13     IndiGo                       Mumbai     06:20           16:10\nMumbai
# 0     GoFirst       DEL Indira Gandhi Intl     06:00                   08:10
# 0     GoFirst                          DEL  06:00\nD                  0\nDEL
# 0   Air India                          BOM    6:45am                  8:30am
#
#    Duration      Price     Route
# 8    5h 55m      4,827  Non stop
# 9   10h 50m      4,827  Non stop
# 10  12h 50m      4,827  Non stop
# 11   5h 40m      5,176  Non stop
# ...

# %%
df['Date']=df['Date'].replace("",np.nan)

# %%
df.isnull().sum()
# Out:
# Names        0
# Date         9
# Places       0
# Departure    0
# Arrival      0
# Duration     0
# Price        0
# Route        0
# dtype: int64

# %%
df.loc[df['Price']=='']
# Out:
#       Names          Date                        Places Departure Arrival  \
# 2   GoFirst  Mon, 14 Feb   BOM Chhatrapati Shivaji Intl     21:20   06:15
# 3   GoFirst  Mon, 14 Feb         DEL Indira Gandhi Intl     15:15   23:05
# 4   GoFirst  Mon, 14 Feb         DEL Indira Gandhi Intl     06:00   08:10
# 5   GoFirst  Mon, 14 Feb   BOM Chhatrapati Shivaji Intl     17:40   19:50
# 9   GoFirst  Mon, 14 Feb   BOM Chhatrapati Shivaji Intl     09:55   12:05
# 13  GoFirst  Mon, 14 Feb   BOM Chhatrapati Shivaji Intl     08:45   10:55
#
#    Duration Price   Route
# 2    8h 55m        1 stop
# 3    7h 50m        1 stop
# 4    2h 10m        direct
# 5    2h 10m        direct
# 9    2h 10m        direct
# 13   2h 10m        direct

# %%
df['Price']=df['Price'].replace("",np.nan)

# %%
df['Date']=df['Date'].fillna(df['Date'].mode()[0])

# %%
df['Price']=df['Price'].fillna(df['Price'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Names        0
# Date         0
# Places       0
# Departure    0
# Arrival      0
# Duration     0
# Price        0
# Route        0
# dtype: int64

# %%
# as we have dealt with white spaces and nulls lets move further

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#     Names  Date  Places  Departure  Arrival  Duration  Price  Route
# 0     2.0   3.0     6.0        2.0      8.0      21.0    0.0    5.0
# 1     6.0   7.0     5.0       21.0      4.0      25.0    1.0    5.0
# 2     6.0   8.0     6.0       16.0      4.0       2.0    1.0    5.0
# 3     6.0   6.0     5.0       11.0      4.0       6.0    1.0    5.0
# 4     6.0   0.0     6.0        6.0      4.0      12.0    1.0    5.0
# 5     6.0   4.0     5.0       21.0      6.0       3.0    4.0    5.0
# 6     6.0   5.0     6.0       16.0      6.0       5.0    4.0    5.0
# 7     6.0   1.0     5.0       11.0      6.0      11.0    4.0    5.0
# 8     0.0   2.0     6.0        1.0      9.0      22.0    5.0    5.0
# 9     0.0   2.0     5.0        7.0     18.0       1.0    5.0    5.0
# 10    0.0   2.0     6.0        7.0     21.0       4.0    5.0    5.0
# 11    4.0   2.0     5.0       10.0     17.0      20.0    7.0    5.0
# 12    4.0   2.0     6.0       22.0      2.0      23.0    9.0    5.0
# ...

# %%
# data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(20,15))
plotnumber=1
for column in df:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
# lets check the outliers using boxplot

# %%
plt.figure(figsize=(20,15))
plotnumber=1
for column in df:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
df.skew()
# Out:
# Names        0.269257
# Date         3.079953
# Places       0.258965
# Departure   -0.026562
# Arrival      0.210442
# Duration    -0.159628
# Price        0.479046
# Route       -1.049744
# dtype: float64

# %%
df['Date']=np.log(df['Date'])

# %%
# split thee dataset into train and test 
from sklearn.model_selection import train_test_split

# %%
#seperating the columns into feature and target

# %%
x=df.drop("Price",axis=1)
y=df['Price']

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=40)

# %%
from sklearn.metrics import accuracy_score,r2_score

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)

# %%
print(f"training accuracy is:{r2_score(y_train,pred_train)}")
print(f"testing accuracy is:{r2_score(y_test,pred_test)}")
# Out:
# training accuracy is:0.48923968568383036
# testing accuracy is:0.2860400214481075

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg=LogisticRegression()
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_train=log_reg.predict(x_train)
pred_test=log_reg.predict(x_test)

# %%
print(f"training accuracy is:{r2_score(y_train,pred_train)}")
print(f"testing accuracy is:{r2_score(y_test,pred_test)}")
# Out:
# training accuracy is:0.6365999213419744
# testing accuracy is:0.28141592920353986

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.concat([flight,flight_1,flight_2,flight_3])
df
# Out:
#                      Names         Date                        Places  \
# 0                 Go First   Mon, 6 Feb                     New Delhi
# 1                  Vistara   Tue, 7 Feb                        Mumbai
# 2                  Vistara   Wed, 8 Feb                     New Delhi
# 3                  Vistara   Thu, 9 Feb                        Mumbai
# 4                  Vistara  Fri, 10 Feb                     New Delhi
# 5                  Vistara  Sat, 11 Feb                        Mumbai
# 6                  Vistara  Sun, 12 Feb                     New Delhi
# 7                  Vistara  Mon, 13 Feb                        Mumbai
# 8                 Air Asia                                  New Delhi
# 9                 Air Asia                                     Mumbai
# 10                Air Asia                                  New Delhi
# 11                  IndiGo                                     Mumbai
# ...

# %%
df.shape
# Out:
# (56, 8)

# %%
df.dtypes
# Out:
# Names        object
# Date         object
# Places       object
# Departure    object
# Arrival      object
# Duration     object
# Price        object
# Route        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Names         0
# Date         42
# Places        0
# Departure     0
# Arrival       0
# Duration      0
# Price         0
# Route        14
# dtype: int64

# %%
# lets treat nulls
df['Date']=df['Date'].fillna(df['Date'].mode())

# %%
df['Route']=df['Route'].fillna("Non stop")

# %%
df.isnull().sum()
# Out:
# Names         0
# Date         39
# Places        0
# Departure     0
# Arrival       0
# Duration      0
# Price         0
# Route         0
# dtype: int64

# %%
print(df["Date"].value_counts())
# Out:
#                9
# Mon, 6 Feb     1
# Tue, 7 Feb     1
# Wed, 8 Feb     1
# Thu, 9 Feb     1
# Fri, 10 Feb    1
# Sat, 11 Feb    1
# Sun, 12 Feb    1
# Mon, 13 Feb    1
# Name: Date, dtype: int64

# %%
print(df["Route"].value_counts())
# Out:
# Non stop     28
# direct       12
# (Direct)      8
# (1 stop)      4
# 1 stop        2
#  (1 stop)     1
# 1 stop)       1
# Name: Route, dtype: int64

# %%
df['Date']=df['Date'].fillna("Sun, 12 Feb")

# %%
df.isnull().sum()
# Out:
# Names        0
# Date         0
# Places       0
# Departure    0
# Arrival      0
# Duration     0
# Price        0
# Route        0
# dtype: int64

# %%
df.loc[df['Date']=='']
# Out:
#         Names Date                  Places Departure                 Arrival  \
# 8    Air Asia                    New Delhi     04:55           10:50\nMumbai
# 9    Air Asia                       Mumbai     08:10           19:00\nMumbai
# 10   Air Asia                    New Delhi     08:10           21:00\nMumbai
# 11     IndiGo                       Mumbai     11:05           16:45\nMumbai
# 12     IndiGo                    New Delhi     23:40  05:50\n+ 1 day\nMumbai
# 13     IndiGo                       Mumbai     06:20           16:10\nMumbai
# 0     GoFirst       DEL Indira Gandhi Intl     06:00                   08:10
# 0     GoFirst                          DEL  06:00\nD                  0\nDEL
# 0   Air India                          BOM    6:45am                  8:30am
#
#    Duration      Price     Route
# 8    5h 55m      4,827  Non stop
# 9   10h 50m      4,827  Non stop
# 10  12h 50m      4,827  Non stop
# 11   5h 40m      5,176  Non stop
# ...

# %%
df.loc[df['Price']=='']
# Out:
#       Names         Date                        Places Departure Arrival  \
# 2   GoFirst  Sun, 12 Feb  BOM Chhatrapati Shivaji Intl     21:20   06:15
# 3   GoFirst  Sun, 12 Feb        DEL Indira Gandhi Intl     15:15   23:05
# 4   GoFirst  Sun, 12 Feb        DEL Indira Gandhi Intl     06:00   08:10
# 5   GoFirst  Sun, 12 Feb  BOM Chhatrapati Shivaji Intl     17:40   19:50
# 9   GoFirst  Sun, 12 Feb  BOM Chhatrapati Shivaji Intl     09:55   12:05
# 13  GoFirst  Sun, 12 Feb  BOM Chhatrapati Shivaji Intl     08:45   10:55
#
#    Duration Price   Route
# 2    8h 55m        1 stop
# 3    7h 50m        1 stop
# 4    2h 10m        direct
# 5    2h 10m        direct
# 9    2h 10m        direct
# 13   2h 10m        direct

# %%
df['Date']=df['Date'].replace("",np.nan)

# %%
df['Price']=df['Price'].replace("",np.nan)

# %%
df.isnull().sum()
# Out:
# Names        0
# Date         9
# Places       0
# Departure    0
# Arrival      0
# Duration     0
# Price        6
# Route        0
# dtype: int64

# %%
df['Date']=df['Date'].fillna(df['Date'].mode()[0])

# %%
df['Price']=df['Price'].fillna(df['Price'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Names        0
# Date         0
# Places       0
# Departure    0
# Arrival      0
# Duration     0
# Price        0
# Route        0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
df2=lab_enc.fit_transform(df['Names'])
df['Names']=df2
df
# Out:
#     Names         Date                        Places Departure  \
# 0       2   Mon, 6 Feb                     New Delhi     05:00
# 1       6   Tue, 7 Feb                        Mumbai     21:20
# 2       6   Wed, 8 Feb                     New Delhi     18:00
# 3       6   Thu, 9 Feb                        Mumbai     13:25
# 4       6  Fri, 10 Feb                     New Delhi     06:30
# 5       6  Sat, 11 Feb                        Mumbai     21:20
# 6       6  Sun, 12 Feb                     New Delhi     18:00
# 7       6  Mon, 13 Feb                        Mumbai     13:25
# 8       0  Sun, 12 Feb                     New Delhi     04:55
# 9       0  Sun, 12 Feb                        Mumbai     08:10
# 10      0  Sun, 12 Feb                     New Delhi     08:10
# 11      4  Sun, 12 Feb                        Mumbai     11:05
# 12      4  Sun, 12 Feb                     New Delhi     23:40
# 13      4  Sun, 12 Feb                        Mumbai     06:20
# ...

# %%
df2=lab_enc.fit_transform(df['Date'])
df['Date']=df2
df
# Out:
#     Names  Date                        Places Departure  \
# 0       2     2                     New Delhi     05:00
# 1       6     6                        Mumbai     21:20
# 2       6     7                     New Delhi     18:00
# 3       6     5                        Mumbai     13:25
# 4       6     0                     New Delhi     06:30
# 5       6     3                        Mumbai     21:20
# 6       6     4                     New Delhi     18:00
# 7       6     1                        Mumbai     13:25
# 8       0     4                     New Delhi     04:55
# 9       0     4                        Mumbai     08:10
# 10      0     4                     New Delhi     08:10
# 11      4     4                        Mumbai     11:05
# 12      4     4                     New Delhi     23:40
# 13      4     4                        Mumbai     06:20
# 0       3     4        DEL Indira Gandhi Intl     06:00
# 1       7     4  BOM Chhatrapati Shivaji Intl     09:55
# ...

# %%
df2=lab_enc.fit_transform(df['Places'])
df['Places']=df2
df
# Out:
#     Names  Date  Places Departure                 Arrival Duration      Price  \
# 0       2     2       6     05:00           10:45\nMumbai   5h 45m      4,093
# 1       6     6       5     21:20  06:15\n+ 1 day\nMumbai   8h 55m      4,102
# 2       6     7       6     18:00  06:15\n+ 1 day\nMumbai  12h 15m      4,102
# 3       6     5       5     13:25  06:15\n+ 1 day\nMumbai  16h 50m      4,102
# 4       6     0       6     06:30  06:15\n+ 1 day\nMumbai  23h 45m      4,102
# 5       6     3       5     21:20  09:40\n+ 1 day\nMumbai  12h 20m      4,737
# 6       6     4       6     18:00  09:40\n+ 1 day\nMumbai  15h 40m      4,737
# 7       6     1       5     13:25  09:40\n+ 1 day\nMumbai  20h 15m      4,737
# 8       0     4       6     04:55           10:50\nMumbai   5h 55m      4,827
# 9       0     4       5     08:10           19:00\nMumbai  10h 50m      4,827
# 10      0     4       6     08:10           21:00\nMumbai  12h 50m      4,827
# ...

# %%
df2=lab_enc.fit_transform(df['Departure'])
df['Departure']=df2
df
# Out:
#     Names  Date  Places  Departure                 Arrival Duration  \
# 0       2     2       6          2           10:45\nMumbai   5h 45m
# 1       6     6       5         21  06:15\n+ 1 day\nMumbai   8h 55m
# 2       6     7       6         16  06:15\n+ 1 day\nMumbai  12h 15m
# 3       6     5       5         11  06:15\n+ 1 day\nMumbai  16h 50m
# 4       6     0       6          6  06:15\n+ 1 day\nMumbai  23h 45m
# 5       6     3       5         21  09:40\n+ 1 day\nMumbai  12h 20m
# 6       6     4       6         16  09:40\n+ 1 day\nMumbai  15h 40m
# 7       6     1       5         11  09:40\n+ 1 day\nMumbai  20h 15m
# 8       0     4       6          1           10:50\nMumbai   5h 55m
# 9       0     4       5          7           19:00\nMumbai  10h 50m
# 10      0     4       6          7           21:00\nMumbai  12h 50m
# 11      4     4       5         10           16:45\nMumbai   5h 40m
# 12      4     4       6         22  05:50\n+ 1 day\nMumbai   6h 10m
# ...

# %%
df2=lab_enc.fit_transform(df['Arrival'])
df['Arrival']=df2
df
# Out:
#     Names  Date  Places  Departure  Arrival Duration      Price      Route
# 0       2     2       6          2        8   5h 45m      4,093   Non stop
# 1       6     6       5         21        4   8h 55m      4,102   Non stop
# 2       6     7       6         16        4  12h 15m      4,102   Non stop
# 3       6     5       5         11        4  16h 50m      4,102   Non stop
# 4       6     0       6          6        4  23h 45m      4,102   Non stop
# 5       6     3       5         21        6  12h 20m      4,737   Non stop
# 6       6     4       6         16        6  15h 40m      4,737   Non stop
# 7       6     1       5         11        6  20h 15m      4,737   Non stop
# 8       0     4       6          1        9   5h 55m      4,827   Non stop
# 9       0     4       5          7       18  10h 50m      4,827   Non stop
# 10      0     4       6          7       21  12h 50m      4,827   Non stop
# ...

# %%
df2=lab_enc.fit_transform(df['Duration'])
df['Duration']=df2
df
# Out:
#     Names  Date  Places  Departure  Arrival  Duration      Price      Route
# 0       2     2       6          2        8        21      4,093   Non stop
# 1       6     6       5         21        4        25      4,102   Non stop
# 2       6     7       6         16        4         2      4,102   Non stop
# 3       6     5       5         11        4         6      4,102   Non stop
# 4       6     0       6          6        4        12      4,102   Non stop
# 5       6     3       5         21        6         3      4,737   Non stop
# 6       6     4       6         16        6         5      4,737   Non stop
# 7       6     1       5         11        6        11      4,737   Non stop
# 8       0     4       6          1        9        22      4,827   Non stop
# 9       0     4       5          7       18         1      4,827   Non stop
# 10      0     4       6          7       21         4      4,827   Non stop
# ...

# %%
df2=lab_enc.fit_transform(df['Route'])
df['Route']=df2
df
# Out:
#     Names  Date  Places  Departure  Arrival  Duration      Price  Route
# 0       2     2       6          2        8        21      4,093      5
# 1       6     6       5         21        4        25      4,102      5
# 2       6     7       6         16        4         2      4,102      5
# 3       6     5       5         11        4         6      4,102      5
# 4       6     0       6          6        4        12      4,102      5
# 5       6     3       5         21        6         3      4,737      5
# 6       6     4       6         16        6         5      4,737      5
# 7       6     1       5         11        6        11      4,737      5
# 8       0     4       6          1        9        22      4,827      5
# 9       0     4       5          7       18         1      4,827      5
# 10      0     4       6          7       21         4      4,827      5
# 11      4     4       5         10       17        20      5,176      5
# ...

# %%
df2=lab_enc.fit_transform(df['Price'])
df['Price']=df2
df
# Out:
#     Names  Date  Places  Departure  Arrival  Duration  Price  Route
# 0       2     2       6          2        8        21      0      5
# 1       6     6       5         21        4        25      1      5
# 2       6     7       6         16        4         2      1      5
# 3       6     5       5         11        4         6      1      5
# 4       6     0       6          6        4        12      1      5
# 5       6     3       5         21        6         3      4      5
# 6       6     4       6         16        6         5      4      5
# 7       6     1       5         11        6        11      4      5
# 8       0     4       6          1        9        22      5      5
# 9       0     4       5          7       18         1      5      5
# 10      0     4       6          7       21         4      5      5
# 11      4     4       5         10       17        20      7      5
# 12      4     4       6         22        2        23      9      5
# ...

# %%
df.dtypes
# Out:
# Names        int32
# Date         int32
# Places       int32
# Departure    int32
# Arrival      int32
# Duration     int32
# Price        int32
# Route        int32
# dtype: object

# %%
df.skew()
# Out:
# Names        0.269257
# Date        -1.453217
# Places       0.258965
# Departure   -0.026562
# Arrival      0.210442
# Duration    -0.159628
# Price        0.479046
# Route       -1.049744
# dtype: float64

# %%
df['Date']=np.log(df['Date'])

# %%
df['Route']=np.log(df['Route'])

# %%
df.skew()
# Out:
# Names        0.269257
# Date        -1.453217
# Places       0.258965
# Departure   -0.026562
# Arrival      0.210442
# Duration    -0.159628
# Price        0.479046
# Route             NaN
# dtype: float64

# %%
df['Date']=np.exp(df['Date'])

# %%
df['Route']=np.exp(df['Route'])

# %%
df.skew()
# Out:
# Names        0.269257
# Date        -1.453217
# Places       0.258965
# Departure   -0.026562
# Arrival      0.210442
# Duration    -0.159628
# Price        0.479046
# Route       -1.049744
# dtype: float64

# %%
for i in range(0,50):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"at random state{i}training accuracy is:{r2_score(y_train,pred_train)}")
    print(f"at random state{i}testing accuracy is:{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# at random state0training accuracy is:0.5117139674169688
# at random state0testing accuracy is:0.08242726987713367
#
#
# at random state1training accuracy is:0.4702449946352931
# at random state1testing accuracy is:0.24832446405276476
#
#
# at random state2training accuracy is:0.3996482424275408
# at random state2testing accuracy is:0.38781775005786223
#
#
# at random state3training accuracy is:0.40891732984155726
# at random state3testing accuracy is:0.5289775665888086
#
#
# at random state4training accuracy is:0.45281339857708747
# at random state4testing accuracy is:0.18050809742557195
#
#
# at random state5training accuracy is:0.49480235410880147
# at random state5testing accuracy is:0.09989928306290918
#
#
# at random state6training accuracy is:0.440421832014229
# at random state6testing accuracy is:0.4463290243970066
#
#
# at random state7training accuracy is:0.39580920678712017
# at random state7testing accuracy is:0.5030382975445462
#
#
# ...

# %%
from sklearn.model_selection import GridSearchCV,cross_val_score
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[.0001,.001,.01,.1,1],
           'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 40.372144805584774

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
parameters={'criterion':['mse','mae'],
           'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion="mae",max_features="sqrt")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print('r2_score',rfs*100)
# Out:
# r2_score 32.03668923734854

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
pred_train=knn.predict(x_train)
pred_test=knn.predict(x_test)
print(f"training accuracy is:{r2_score(y_train,pred_train)}")
print(f"testing accuracy is:{r2_score(y_test,pred_test)}")
print("\n")
# Out:
# training accuracy is:0.45515004840271056
# testing accuracy is:-0.08202423378474699

# %%
#regression models are good for this type of dataset

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
pred_train=knc.predict(x_train)
pred_test=knc.predict(x_test)
print(f"training accuracy is:{r2_score(y_train,pred_train)}")
print(f"testing accuracy is:{r2_score(y_test,pred_test)}")
print("\n")
# Out:
# training accuracy is:0.24201355275895442
# testing accuracy is:-0.1176051318602993

# %%
#regression models are good for this type of dataset
