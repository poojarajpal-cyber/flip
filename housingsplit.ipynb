# %%
import numpy as np
import pandas as pd

# %%
data_1=pd.read_csv(r'D:/Project-Housing_splitted/test.csv')
data_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
data_2=pd.read_csv(r"D:/Project-Housing_splitted/train.csv")
data_2.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data_1.shape
# Out:
# (292, 80)

# %%
data_2.shape
# Out:
# (1168, 81)

# %%
df=pd.concat([data_1,data_2])
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN   NaN         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN   NaN         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      1
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
# checking for other information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# checking for nulls
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice        292
# Length: 81, dtype: int64

# %%
# lets check for zeros
count=(df==0).sum()
count
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
df_1=df.copy()

# %%
df_1['LotFrontage']=df_1['LotFrontage'].fillna(df_1['LotFrontage'].mean())

# %%
df_1['MasVnrArea']=df_1['MasVnrArea'].fillna(df_1['MasVnrArea'].mean())

# %%
print(df_1["MasVnrType"].value_counts())
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
df_1['MasVnrType']=df_1['MasVnrType'].fillna('None')

# %%
print(df_1["BsmtQual"].value_counts())
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
df_1['BsmtQual']=df_1['BsmtQual'].fillna('TA')

# %%
print(df_1["BsmtCond"].value_counts())
# Out:
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64

# %%
df_1['BsmtCond']=df_1['BsmtCond'].fillna('TA')

# %%
print(df_1["BsmtExposure"].value_counts())
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
df_1['BsmtExposure']=df_1['BsmtExposure'].fillna('No')

# %%
print(df_1["BsmtFinType1"].value_counts())
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
df_1['BsmtFinType1']=df_1['BsmtFinType1'].fillna('Unf')

# %%
print(df_1["Electrical"].value_counts())
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
df_1['BsmtFinType1']=df_1['BsmtFinType1'].fillna('SBrkr')

# %%
print(df_1["FireplaceQu"].value_counts())
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
df_1['FireplaceQu']=df_1['FireplaceQu'].fillna('Gd')

# %%
print(df_1["GarageType"].value_counts())
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
df_1['GarageType']=df_1['GarageType'].fillna('Attchd')

# %%
print(df_1["GarageYrBlt"].value_counts())
# Out:
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
#           ..
# 1927.0     1
# 1900.0     1
# 1908.0     1
# 1933.0     1
# 1906.0     1
# Name: GarageYrBlt, Length: 97, dtype: int64

# %%
df_1['GarageYrBlt']=df_1['GarageYrBlt'].fillna(2005.0)

# %%
print(df_1["GarageFinish"].value_counts())
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64

# %%
df_1['GarageFinish']=df_1['GarageFinish'].fillna('Unf')

# %%
print(df_1["GarageQual"].value_counts())
# Out:
# TA    1311
# Fa      48
# Gd      14
# Po       3
# Ex       3
# Name: GarageQual, dtype: int64

# %%
df_1['GarageQual']=df_1['GarageQual'].fillna('TA')

# %%
print(df_1["GarageCond"].value_counts())
# Out:
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %%
df_1['GarageCond']=df_1['GarageCond'].fillna('TA')

# %%
print(df_1["Fence"].value_counts())
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64

# %%
df_1['Fence']=df_1['Fence'].fillna('MnPrv')

# %%
df_1['SalePrice']=df_1['SalePrice'].fillna(df_1['SalePrice'].mean())

# %%
df_1.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
# now we have dealt with nulls lets move further

# %%
#data visualization
# for that importing necessary libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# before that there are object datatype columns 
# lets encode them using label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
df2=lab_enc.fit_transform(df_1['SaleCondition'])

df_1['SaleCondition']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         HLS    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 2         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3         Bnk    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['SaleType'])

df_1['SaleType']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         HLS    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 2         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3         Bnk    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['Fence'])

df_1['Fence']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df_1.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType           int32
# SaleCondition      int32
# SalePrice        float64
# Length: 81, dtype: object

# %%
df2=lab_enc.fit_transform(df_1['PavedDrive'])

df_1['PavedDrive']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['GarageCond'])

df_1['GarageCond']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['GarageQual'])

df_1['GarageQual']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['GarageFinish'])

df_1['GarageFinish']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['GarageType'])

df_1['GarageType']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['FireplaceQu'])

df_1['FireplaceQu']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['Functional'])

df_1['Functional']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['KitchenQual'])

df_1['KitchenQual']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df2=lab_enc.fit_transform(df_1['Electrical'])

df_1['Electrical']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['CentralAir'])

df_1['CentralAir']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['HeatingQC'])

df_1['HeatingQC']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['Heating'])

df_1['Heating']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['BsmtFinType2'])

df_1['BsmtFinType2']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['BsmtFinType1'])

df_1['BsmtFinType1']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['BsmtExposure'])

df_1['BsmtExposure']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['BsmtCond'])

df_1['BsmtCond']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['BsmtQual'])

df_1['BsmtQual']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['Foundation'])

df_1['Foundation']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['ExterCond'])

df_1['ExterCond']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['ExterQual'])

df_1['ExterQual']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['MasVnrType'])

df_1['MasVnrType']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['Exterior2nd'])

df_1['Exterior2nd']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['Exterior1st'])

df_1['Exterior1st']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['RoofMatl'])

df_1['RoofMatl']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['RoofStyle'])

df_1['RoofStyle']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#   YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['HouseStyle'])

df_1['HouseStyle']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0      1
#
#    YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['BldgType'])

df_1['BldgType']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN       0
# 1         Lvl    AllPub  ...        0    NaN     2         NaN       0
# 2         Lvl    AllPub  ...        0    NaN     2         NaN       0
# 3         Bnk    AllPub  ...        0    NaN     2         NaN       0
# 4         Lvl    AllPub  ...        0    NaN     2         NaN       0
#
#    MoSold  YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['Condition2'])

df_1['Condition2']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 0         HLS    AllPub  ...        0    NaN     2         NaN        0
# 1         Lvl    AllPub  ...        0    NaN     2         NaN        0
# 2         Lvl    AllPub  ...        0    NaN     2         NaN        0
# 3         Bnk    AllPub  ...        0    NaN     2         NaN        0
# 4         Lvl    AllPub  ...        0    NaN     2         NaN        0
#
#    MoSold  YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['Condition1'])

df_1['Condition1']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence  MiscFeature  MiscVal  \
# 0         HLS    AllPub  ...        0    NaN     2          NaN        0
# 1         Lvl    AllPub  ...        0    NaN     2          NaN        0
# 2         Lvl    AllPub  ...        0    NaN     2          NaN        0
# 3         Bnk    AllPub  ...        0    NaN     2          NaN        0
# 4         Lvl    AllPub  ...        0    NaN     2          NaN        0
#
#    MoSold  YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['Neighborhood'])

df_1['Neighborhood']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence  MiscFeature  MiscVal  \
# 0         HLS    AllPub  ...        0    NaN      2          NaN        0
# 1         Lvl    AllPub  ...        0    NaN      2          NaN        0
# 2         Lvl    AllPub  ...        0    NaN      2          NaN        0
# 3         Bnk    AllPub  ...        0    NaN      2          NaN        0
# 4         Lvl    AllPub  ...        0    NaN      2          NaN        0
#
#    MoSold  YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['LandSlope'])

df_1['LandSlope']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0         HLS    AllPub  ...        0     NaN      2          NaN        0
# 1         Lvl    AllPub  ...        0     NaN      2          NaN        0
# 2         Lvl    AllPub  ...        0     NaN      2          NaN        0
# 3         Bnk    AllPub  ...        0     NaN      2          NaN        0
# 4         Lvl    AllPub  ...        0     NaN      2          NaN        0
#
#    MoSold  YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['LotConfig'])

df_1['LotConfig']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0         HLS    AllPub  ...         0     NaN      2          NaN        0
# 1         Lvl    AllPub  ...         0     NaN      2          NaN        0
# 2         Lvl    AllPub  ...         0     NaN      2          NaN        0
# 3         Bnk    AllPub  ...         0     NaN      2          NaN        0
# 4         Lvl    AllPub  ...         0     NaN      2          NaN        0
#
#    MoSold  YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['Utilities'])

df_1['Utilities']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#   LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0         HLS          0  ...         0     NaN      2          NaN        0
# 1         Lvl          0  ...         0     NaN      2          NaN        0
# 2         Lvl          0  ...         0     NaN      2          NaN        0
# 3         Bnk          0  ...         0     NaN      2          NaN        0
# 4         Lvl          0  ...         0     NaN      2          NaN        0
#
#    MoSold  YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['LandContour'])

df_1['LandContour']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1  1018         120       RL    70.049958     5814   Pave   NaN      IR1
# 2   929          20       RL    70.049958    11838   Pave   NaN      Reg
# 3  1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4  1227          60       RL    86.000000    14598   Pave   NaN      IR1
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            1          0  ...         0     NaN      2          NaN        0
# 1            3          0  ...         0     NaN      2          NaN        0
# 2            3          0  ...         0     NaN      2          NaN        0
# 3            0          0  ...         0     NaN      2          NaN        0
# 4            3          0  ...         0     NaN      2          NaN        0
#
#    MoSold  YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
df2=lab_enc.fit_transform(df_1['LotShape'])

df_1['LotShape']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  LotShape  \
# 0   337          20       RL    86.000000    14157   Pave   NaN         0
# 1  1018         120       RL    70.049958     5814   Pave   NaN         0
# 2   929          20       RL    70.049958    11838   Pave   NaN         3
# 3  1148          70       RL    75.000000    12000   Pave   NaN         3
# 4  1227          60       RL    86.000000    14598   Pave   NaN         0
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            1          0  ...         0     NaN      2          NaN        0
# 1            3          0  ...         0     NaN      2          NaN        0
# 2            3          0  ...         0     NaN      2          NaN        0
# 3            0          0  ...         0     NaN      2          NaN        0
# 4            3          0  ...         0     NaN      2          NaN        0
#
# ...

# %%
df2=lab_enc.fit_transform(df_1['Street'])

df_1['Street']=df2
df_1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea  Street Alley  LotShape  \
# 0   337          20       RL    86.000000    14157       1   NaN         0
# 1  1018         120       RL    70.049958     5814       1   NaN         0
# 2   929          20       RL    70.049958    11838       1   NaN         3
# 3  1148          70       RL    75.000000    12000       1   NaN         3
# 4  1227          60       RL    86.000000    14598       1   NaN         0
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            1          0  ...         0     NaN      2          NaN        0
# 1            3          0  ...         0     NaN      2          NaN        0
# 2            3          0  ...         0     NaN      2          NaN        0
# 3            0          0  ...         0     NaN      2          NaN        0
# 4            3          0  ...         0     NaN      2          NaN        0
#
# ...

# %%
df2=lab_enc.fit_transform(df_1['MSZoning'])

df_1['MSZoning']=df2
df_1.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street Alley  LotShape  \
# 0   337          20         3    86.000000    14157       1   NaN         0
# 1  1018         120         3    70.049958     5814       1   NaN         0
# 2   929          20         3    70.049958    11838       1   NaN         3
# 3  1148          70         3    75.000000    12000       1   NaN         3
# 4  1227          60         3    86.000000    14598       1   NaN         0
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            1          0  ...         0     NaN      2          NaN        0
# 1            3          0  ...         0     NaN      2          NaN        0
# 2            3          0  ...         0     NaN      2          NaN        0
# 3            0          0  ...         0     NaN      2          NaN        0
# 4            3          0  ...         0     NaN      2          NaN        0
#
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int32
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int32
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   int32
#  8   LandContour    1460 non-null   int32
#  9   Utilities      1460 non-null   int32
#  10  LotConfig      1460 non-null   int32
#  11  LandSlope      1460 non-null   int32
#  12  Neighborhood   1460 non-null   int32
#  13  Condition1     1460 non-null   int32
#  14  Condition2     1460 non-null   int32
#  15  BldgType       1460 non-null   int32
#  16  HouseStyle     1460 non-null   int32
#  17  OverallQual    1460 non-null   int64
# ...

# %%
# we are deleting 3 columns as it has so many nulls
df_1=df_1.drop(columns=['MiscFeature','PoolQC','Alley'],axis=1)

# %%
print(df_1.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
df_1.shape
# Out:
# (1460, 78)

# %%
# data visualization

# %%
#data visualization
plt.figure(figsize=(20,15))
plotnumber=1
for column in df_1:
    if plotnumber<=78:
        ax=plt.subplot(13,6,plotnumber)
        sns.distplot(df_1[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#there is lot of skewness in the dataset 
# lets check

# %%
print(df_1.skew()[0:11])
# Out:
# Id              0.000000
# MSSubClass      1.407657
# MSZoning       -1.735395
# LotFrontage     2.384950
# LotArea        12.207688
# Street        -15.518770
# LotShape       -0.610175
# LandContour    -3.162499
# Utilities      38.209946
# LotConfig      -1.135632
# LandSlope       4.813682
# dtype: float64

# %%
# lets treatthe skewness

# %%
from sklearn.preprocessing import PowerTransformer

# %%
scaler=PowerTransformer(method='yeo-johnson')

# %%
print(df_1.skew()[11:21])
# Out:
# Neighborhood     0.042122
# Condition1       3.019196
# Condition2      13.171844
# BldgType         2.245648
# HouseStyle       0.306755
# OverallQual      0.216944
# OverallCond      0.693067
# YearBuilt       -0.613461
# YearRemodAdd    -0.503562
# RoofStyle        1.473796
# dtype: float64

# %%
print(df_1.skew()[21:31])
# Out:
# RoofMatl       8.109402
# Exterior1st   -0.726314
# Exterior2nd   -0.692963
# MasVnrType    -0.073627
# MasVnrArea     2.676412
# ExterQual     -1.830265
# ExterCond     -2.565305
# Foundation     0.091217
# BsmtQual      -1.344288
# BsmtCond      -3.456505
# dtype: float64

# %%
print(df_1.skew()[31:41])
# Out:
# BsmtExposure   -1.189376
# BsmtFinType1   -0.061029
# BsmtFinSF1      1.685503
# BsmtFinType2   -3.406104
# BsmtFinSF2      4.255261
# BsmtUnfSF       0.920268
# TotalBsmtSF     1.524255
# Heating         9.855100
# HeatingQC       0.483218
# CentralAir     -3.530386
# dtype: float64

# %%
print(df_1.skew()[41:51])
# Out:
# Electrical     -3.059107
# 1stFlrSF        1.376757
# 2ndFlrSF        0.813030
# LowQualFinSF    9.011341
# GrLivArea       1.366560
# BsmtFullBath    0.596067
# BsmtHalfBath    4.103403
# FullBath        0.036562
# HalfBath        0.675897
# BedroomAbvGr    0.211790
# dtype: float64

# %%
print(df_1.skew()[51:61])
# Out:
# KitchenAbvGr    4.488397
# KitchenQual    -1.422808
# TotRmsAbvGrd    0.676341
# Functional     -4.084958
# Fireplaces      0.649565
# FireplaceQu     0.791903
# GarageType      0.853020
# GarageYrBlt    -0.719292
# GarageFinish   -0.440519
# GarageCars     -0.342549
# dtype: float64

# %%
print(df_1.skew()[61:71])
# Out:
# GarageArea        0.179981
# GarageQual       -4.587825
# GarageCond       -5.455517
# PavedDrive       -3.308938
# WoodDeckSF        1.541376
# OpenPorchSF       2.364342
# EnclosedPorch     3.089872
# 3SsnPorch        10.304342
# ScreenPorch       4.122214
# PoolArea         14.828374
# dtype: float64

# %%
print(df_1.skew()[71:78])
# Out:
# Fence            -3.364666
# MiscVal          24.476794
# MoSold            0.212053
# YrSold            0.096269
# SaleType         -3.868638
# SaleCondition    -2.741167
# SalePrice         2.183940
# dtype: float64

# %%
features=['SaleCondition','SaleType','MiscVal','Fence','PoolArea','ScreenPorch','3SsnPorch','EnclosedPorch','OpenPorchSF','WoodDeckSF','PavedDrive','GarageCond','GarageQual','GarageYrBlt','GarageType','FireplaceQu','Fireplaces','Functional','TotRmsAbvGrd','KitchenQual','KitchenAbvGr','HalfBath','BsmtHalfBath','GrLivArea','LowQualFinSF','2ndFlrSF','1stFlrSF','Electrical']

# %%
feat=['CentralAir','Heating','TotalBsmtSF','BsmtUnfSF','BsmtFinSF2','BsmtFinType2','BsmtFinSF1','BsmtExposure','BsmtCond','BsmtQual','ExterCond','ExterQual','MasVnrArea','Exterior2nd','Exterior1st','RoofMatl','RoofStyle','YearBuilt','OverallCond','BldgType','Condition2','Condition1','LandSlope','LotConfig','Utilities','LandContour','LotShape','Street','LotFrontage','LotArea','MSZoning','MSSubClass']

# %%
df_1[features]=scaler.fit_transform(df_1[features].values)
df_1[features]
# Out:
#       SaleCondition  SaleType   MiscVal     Fence  PoolArea  ScreenPorch  \
# 0          0.032281  0.388981 -0.192177  0.169818 -0.069409    -0.293785
# 1         -2.599251 -2.836799 -0.192177  0.169818 -0.069409    -0.293785
# 2          0.032281  0.388981 -0.192177  0.169818 -0.069409    -0.293785
# 3          0.032281  0.388981 -0.192177  0.169818 -0.069409    -0.293785
# 4          0.032281  0.388981 -0.192177  0.169818 -0.069409    -0.293785
# ...             ...       ...       ...       ...       ...          ...
# 1163       0.032281  0.388981 -0.192177  0.169818 -0.069409    -0.293785
# 1164       0.032281  0.388981 -0.192177  0.169818 -0.069409    -0.293785
# 1165       0.032281  0.388981 -0.192177  0.169818 -0.069409    -0.293785
# 1166       0.032281  0.388981 -0.192177  0.169818 -0.069409    -0.293785
# 1167       0.032281  0.388981 -0.192177  0.169818 -0.069409    -0.293785
#
#       3SsnPorch  EnclosedPorch  OpenPorchSF  WoodDeckSF  ...  TotRmsAbvGrd  \
# ...

# %%
df_1[feat]=scaler.fit_transform(df_1[feat].values)
df_1[feat]
# Out:
#       CentralAir   Heating  TotalBsmtSF  BsmtUnfSF  BsmtFinSF2  BsmtFinType2  \
# 0       0.263813 -0.098742     1.842300   0.441958   -0.359384      0.184682
# 1       0.263813 -0.098742     0.417807  -0.757157   -0.359384      0.184682
# 2       0.263813 -0.098742     1.513944   1.938575   -0.359384      0.184682
# 3       0.263813 -0.098742    -0.773259  -0.059700   -0.359384      0.184682
# 4       0.263813 -0.098742    -0.314484   0.817756   -0.359384      0.184682
# ...          ...       ...          ...        ...         ...           ...
# 1163    0.263813 -0.098742    -0.342653  -0.052722   -0.359384      0.184682
# 1164    0.263813 -0.098742    -3.131482  -2.064084   -0.359384      3.750769
# 1165    0.263813 -0.098742    -0.406399  -0.419972   -0.359384      0.184682
# 1166   -3.790570 -0.098742    -0.911841   0.397432   -0.359384      0.184682
# 1167    0.263813 -0.098742    -0.579021  -0.317142   -0.359384      0.184682
#
# ...

# %%
# data correlation using heatmap

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=df_1.drop(columns=['SalePrice'],axis=1)
y=df_1['SalePrice']

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_scaled.shape
# Out:
# (1460, 77)

# %%
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaled,i)for i in range(x_scaled.shape[1])]
vif["features"]=x.columns

# %%
vif[0:11]
# Out:
#          vif     features
# 0   1.060799           Id
# 1   7.078687   MSSubClass
# 2   1.441101     MSZoning
# 3   2.082062  LotFrontage
# 4   2.808226      LotArea
# 5   1.174620       Street
# 6   1.311379     LotShape
# 7   1.550464  LandContour
# 8   1.095363    Utilities
# 9   1.164846    LotConfig
# 10  1.644980    LandSlope

# %%
vif[11:21]
# Out:
#           vif      features
# 11   1.261305  Neighborhood
# 12   1.151957    Condition1
# 13   1.084559    Condition2
# 14   5.216998      BldgType
# 15   2.683376    HouseStyle
# 16   4.137566   OverallQual
# 17   1.943791   OverallCond
# 18  10.140474     YearBuilt
# 19   2.982929  YearRemodAdd
# 20   1.315666     RoofStyle

# %%
vif[21:31]
# Out:
#          vif     features
# 21  1.339483     RoofMatl
# 22  4.430794  Exterior1st
# 23  4.430581  Exterior2nd
# 24  1.598557   MasVnrType
# 25  2.046928   MasVnrArea
# 26  2.994203    ExterQual
# 27  1.223506    ExterCond
# 28  2.240733   Foundation
# 29  2.559377     BsmtQual
# 30  1.156550     BsmtCond

# %%
vif[31:41]
# Out:
#          vif      features
# 31  1.651590  BsmtExposure
# 32  3.181866  BsmtFinType1
# 33  7.199710    BsmtFinSF1
# 34  6.326486  BsmtFinType2
# 35  5.524674    BsmtFinSF2
# 36  5.840907     BsmtUnfSF
# 37  8.917819   TotalBsmtSF
# 38  1.181454       Heating
# 39  1.696399     HeatingQC
# 40  1.663619    CentralAir

# %%
vif[41:51]
# Out:
#           vif      features
# 41   1.388277    Electrical
# 42  19.052545      1stFlrSF
# 43  20.380411      2ndFlrSF
# 44   1.426528  LowQualFinSF
# 45  31.107058     GrLivArea
# 46   2.365991  BsmtFullBath
# 47   1.241113  BsmtHalfBath
# 48   3.191205      FullBath
# 49   2.524333      HalfBath
# 50   2.685489  BedroomAbvGr

# %%
vif[51:61]
# Out:
#          vif      features
# 51  1.711765  KitchenAbvGr
# 52  2.173553   KitchenQual
# 53  5.077606  TotRmsAbvGrd
# 54  1.292276    Functional
# 55  1.914701    Fireplaces
# 56  1.355900   FireplaceQu
# 57  1.517368    GarageType
# 58  3.413437   GarageYrBlt
# 59  2.072425  GarageFinish
# 60  6.264366    GarageCars

# %%
vif[61:71]
# Out:
#          vif       features
# 61  5.715603     GarageArea
# 62  1.624113     GarageQual
# 63  1.595652     GarageCond
# 64  1.486183     PavedDrive
# 65  1.358548     WoodDeckSF
# 66  1.531385    OpenPorchSF
# 67  1.422152  EnclosedPorch
# 68  1.069739      3SsnPorch
# 69  1.140483    ScreenPorch
# 70  1.195088       PoolArea

# %%
vif[71:78]
# Out:
#          vif       features
# 71  1.085146          Fence
# 72  1.118477        MiscVal
# 73  1.085451         MoSold
# 74  1.113919         YrSold
# 75  1.361838       SaleType
# 76  1.409070  SaleCondition

# %%
# if vif score is less than 5 then there is no multicollinearity

# %%
df_corr=df_1.corr().abs()
df_corr

# %%
plt.figure(figsize=(65,60))
sns.heatmap(df_corr,annot=True,annot_kws={'size':10})
plt.show()

# %%
# there seems strong correlation between exterior 1st and exterior 2nd
# also between BsmtFinSF2 and BsmtFinType1
# between TotRmsAbvGrd and GrlLivArea
# and between GarageArea and GarageCars

# %%
import matplotlib.pyplot as plot

# %%
# lets check using scatter plot
df_1.plot.scatter(x='Exterior1st',y='Exterior2nd',title="scatter plot")
plot.show()

# %%
# there seems no such correlation between exterior1st and exterior 2nd 
# so we will keep both of these

# %%
# lets check using scatter plot
df_1.plot.scatter(x='BsmtFinSF2',y='BsmtFinType2',title="scatter plot")
plot.show()

# %%
# lets check using scatter plot
df_1.plot.scatter(x='TotRmsAbvGrd',y='GrLivArea',title="scatter plot")
plot.show()

# %%
# there is strong correlation between the above two columns
# sowe will delete one column

# %%
# lets check using scatter plot
df_1.plot.scatter(x='GarageArea',y='GarageCars',title="scatter plot")
plot.show()

# %%
# also there is correlation between Garage area and garage cars 
# so we will delete one column

# %%
df_1=df_1.drop(columns=['GrLivArea','GarageCars'],axis=1)

# %%
#lets divide the dataset into features and label
x=df_1.drop(columns=['SalePrice'],axis=1)
y=df_1['SalePrice']

# %%
# lets import necessary libraries to build a model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import accuracy_score,r2_score,classification_report,confusion_matrix
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor

# %%
lr=LinearRegression()

# %%
for i in range(0,50):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"at random state{i}the training accuracy is{r2_score(y_train,pred_train)}")
    print(f"at random state{i}the testing accuracy is{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# at random state0the training accuracy is0.6793829056307057
# at random state0the testing accuracy is0.6035217893278018
#
#
# at random state1the training accuracy is0.7041874150182375
# at random state1the testing accuracy is0.5148383621422289
#
#
# at random state2the training accuracy is0.6853523367169969
# at random state2the testing accuracy is-5.095649939235297e+18
#
#
# at random state3the training accuracy is0.6704775005926554
# at random state3the testing accuracy is0.6191611720053343
#
#
# at random state4the training accuracy is0.6937296212004042
# at random state4the testing accuracy is0.5603448551029901
#
#
# at random state5the training accuracy is0.6978364602540668
# at random state5the testing accuracy is-9.45954666552148e+19
#
#
# at random state6the training accuracy is0.6940911806241895
# at random state6the testing accuracy is-7.640579006482606e+19
#
#
# at random state7the training accuracy is0.6603131342518904
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=16)

# %%
# training the model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# checking the accuracy
pred_test=lr.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.6618073265019697

# %%
#regularization
parameters={'alpha':[.0001,.001,.01,.1,1],
           'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=.0001,random_state=0)
ls.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.0001, random_state=0)

# %%
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 66.18073316626602

# %%
#ensemble technique
parameters={'criterion':['mse','mae'],
           'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='log2')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print('r2_score',rfs*100)
# Out:
# r2_score 71.69934561914127

# %%
# lets save the model
import pickle

# %%
pickle.dump(rf,open('housing','wb'))

# %%
loaded_model=pickle.load(open('housing','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 71.69934561914127

# %%
#============thank you==============
